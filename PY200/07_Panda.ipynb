# %% [markdown]
# ## Panda
# ## complex data structure to mimic relational table in python

# %%
## installion
## import

import pandas as pd

# %%
list1 =[10,80,30.8,40,50,60,70]
print(type(list1))

s=pd.Series(list1)

print(type(s))
print(s)
# Out:
# <class 'list'>
# <class 'pandas.Series'>
# 0    10.0
# 1    80.0
# 2    30.8
# 3    40.0
# 4    50.0
# 5    60.0
# 6    70.0
# dtype: float64

# %%
## Series vs Dataframe

s2 =pd.Series(["Math", "sc", "ssc", "art","music","eng", "hindi"])
print(type(s2))
print(s2)
# Out:
# <class 'pandas.Series'>
# 0     Math
# 1       sc
# 2      ssc
# 3      art
# 4    music
# 5      eng
# 6    hindi
# dtype: str

# %%
df1 = pd.DataFrame([s,s2])

# %%
data =[s,s2]
data
# Out:
# [0    10.0
#  1    80.0
#  2    30.8
#  3    40.0
#  4    50.0
#  5    60.0
#  6    70.0
#  dtype: float64,
#  0     Math
#  1       sc
#  2      ssc
#  3      art
#  4    music
#  5      eng
#  6    hindi
#  dtype: str]

# %%
df2 = pd.DataFrame(data)
df2
# Out:
#       0     1     2     3      4     5      6
# 0  10.0  80.0  30.8  40.0   50.0  60.0   70.0
# 1  Math    sc   ssc   art  music   eng  hindi

# %%
print(type(df1))
print(df1)
# Out:
# <class 'pandas.DataFrame'>
#       0     1     2     3      4     5      6
# 0  10.0  80.0  30.8  40.0   50.0  60.0   70.0
# 1  Math    sc   ssc   art  music   eng  hindi

# %%
df1 = pd.DataFrame(s,columns=["Subject1","Subject2","Subject3","Subject4","Subject5","Subject6","Subject7",])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df1 = pd.DataFrame(s,columns=["Subject1","Subject2","Subject3","Subject4","Subject5","Subject6","Subject7",])
#
# File c:\Projects\Github\Python-DataScience-Masterclass\.venv\Lib\site-packages\pandas\core\frame.py:814, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     804         mgr = dict_to_mgr(
#     805             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     806             # attribute "name"
#    (...)    811             copy=copy,
#     812         )
#     813     else:
# --> 814         mgr = ndarray_to_mgr(
#     815             data,
#     816             index,
#     817             columns,
#     818             dtype=dtype,
#     819             copy=copy,
#     820         )
# ...

# %%
d1 = { ["Math" : 10],
      ["sc" :20],
      ["ssc":30],
      ["arts":40],
      ["music":50],
       ["eng": 70],
      [ "hindi":90]

}
d1
# Out:
#   Cell In[48], line 1
#     d1 = { ["Math" : 10],
#                    ^
# SyntaxError: invalid syntax

# %%
df1 =pd.DataFrame(d1)
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df1 =pd.DataFrame(d1)
#       2 df1
#
# File c:\Projects\Github\Python-DataScience-Masterclass\.venv\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
#     768     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770 elif isinstance(data, ma.MaskedArray):
#     771     from numpy.ma import mrecords
#
# ...

# %%
data =[
    [ "07-Jan-2026",	"Falcons",	"Comets",	"River Court"	," Zara",	"Grade", 6,	22,	29,	1	,3	,4,	2628,	"Coach Maya",	"Win"],
     [ "09-Jan-2026",	"Falcons",  "Comets",	"Central Dome",	"Zara",	"Grade", 5	,35,	12,	11,	14,	1,	2739,	"Coach Maya",	"Loss"]
]

df3 = pd.DataFrame(data,columns=['Match_Date','Team',	'Opponent',	'Venue',	'Player',	'Grade',	
                                 'Minutes_Played',	'Points_Scored',	'Assists',	'Rebounds',	'Fouls',	'Ticket_Sales',	'Coach',	'Match_Result',"extra"])
df3
# Out:
#     Match_Date     Team Opponent         Venue Player  Grade  Minutes_Played  \
# 0  07-Jan-2026  Falcons   Comets   River Court   Zara  Grade               6
# 1  09-Jan-2026  Falcons   Comets  Central Dome   Zara  Grade               5
#
#    Points_Scored  Assists  Rebounds  Fouls  Ticket_Sales  Coach Match_Result  \
# 0             22       29         1      3             4   2628   Coach Maya
# 1             35       12        11     14             1   2739   Coach Maya
#
#   extra
# 0   Win
# 1  Loss

# %%
df3[:][0]
# Out:
# 0    07-Jan-2026
# 1    09-Jan-2026
# Name: 0, dtype: str

# %%
df4=pd.read_csv("./src/excel_100_practice_workbooks.csv")
df4
# Out:
#      Match Date     Team  Opponent                  Venue  Player    Grade  \
# 0   07-Jan-2026  Falcons    Comets            River Court    Zara  Grade 6
# 1   09-Jan-2026  Falcons    Comets           Central Dome    Zara  Grade 5
# 2   11-Jan-2026  Falcons   Rockets               Sky Hall    Lily  Grade 7
# 3   13-Jan-2026   Tigers     Storm            River Court   Aarav  Grade 8
# 4   15-Jan-2026   Sharks    Comets            North Arena    Ryan  Grade 6
# 5   17-Jan-2026   Tigers   Rockets            River Court    Lily  Grade 6
# 6   19-Jan-2026   Sharks   Rockets               Sky Hall   Ethan  Grade 7
# 7   21-Jan-2026   Sharks    Comets            River Court   Ethan  Grade 7
# 8   23-Jan-2026   Wolves  Panthers           Central Dome  Ishaan  Grade 6
# 9   25-Jan-2026   Wolves     Storm           Central Dome    Noah  Grade 8
# 10  27-Jan-2026   Wolves   Knights            North Arena   Ethan  Grade 8
# ...

# %%
df4=pd.read_csv(".\src\excel_100_practice_workbooks.csv")
df4
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\shrip\AppData\Local\Temp\ipykernel_32968\2226792748.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df4=pd.read_csv(".\src\excel_100_practice_workbooks.csv")
# C:\Users\shrip\AppData\Local\Temp\ipykernel_32968\2226792748.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df4=pd.read_csv(".\src\excel_100_practice_workbooks.csv")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df4=pd.read_csv(".\src\excel_100_practice_workbooks.csv")
#       2 df4
#
# NameError: name 'pd' is not defined

# %%
df6,df7 = pd.read_excel("file_name.xlsx",sheet_name=["sheet1","sheet2"])

# %%
df4=pd.read_csv(".\src\excel_100_practice_workbooks.csv")
df4
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\shrip\AppData\Local\Temp\ipykernel_32968\2226792748.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df4=pd.read_csv(".\src\excel_100_practice_workbooks.csv")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df4=pd.read_csv(".\src\excel_100_practice_workbooks.csv")
#       2 df4
#
# NameError: name 'pd' is not defined

# %%
data = {
    'Subject' : ['maths','english','science','sst'],
    'Marks' : [30,40,50,60]

}

df3 = pd.DataFrame(data)
print(df3)
# Out:
#    Subject  Marks
# 0    maths     30
# 1  english     40
# 2  science     50
# 3      sst     60

# %%
df4.head(3)
# Out:
#     Match Date     Team Opponent         Venue Player    Grade  \
# 0  07-Jan-2026  Falcons   Comets   River Court   Zara  Grade 6
# 1  09-Jan-2026  Falcons   Comets  Central Dome   Zara  Grade 5
# 2  11-Jan-2026  Falcons  Rockets      Sky Hall   Lily  Grade 7
#
#    Minutes Played  Points Scored Assists Rebounds  Fouls Ticket Sales ($)  \
# 0            22.0           29.0       1        3    4.0           $2,628
# 1            35.0           12.0      11       14    1.0           $2,739
# 2            22.0           12.0       5        4    0.0           $2,456
#
#         Coach Match Result
# 0  Coach Maya          Win
# 1  Coach Maya         Loss
# 2  Coach Maya          Win

# %%
df4.columns
# Out:
# Index(['Match Date', 'Team', 'Opponent', 'Venue', 'Player', 'Grade',
#        'Minutes Played', 'Points Scored', 'Assists', 'Rebounds', 'Fouls',
#        'Ticket Sales ($)', 'Coach', 'Match Result'],
#       dtype='str')

# %%
df4["Points Scored"]
# Out:
# 0     29.0
# 1     12.0
# 2     12.0
# 3      9.0
# 4      8.0
# 5     14.0
# 6     28.0
# 7     12.0
# 8     29.0
# 9     30.0
# 10    20.0
# 11    15.0
# 12    22.0
# 13    17.0
# 14    27.0
# 15    27.0
# 16    24.0
# 17     8.0
# 18    31.0
# 19    27.0
# 20    19.0
# 21    30.0
# 22    18.0
# 23    29.0
# 24    22.0
# 25    25.0
# 26    10.0
# 27    14.0
# 28    31.0
# 29    10.0
# 30    26.0
# 31    28.0
# 32    15.0
# 33    33.0
# 34     9.0
# 35    27.0
# 36     9.0
# 37    25.0
# 38    19.0
# 39    18.0
# 40     NaN
# 41     NaN
# 42     NaN
# 43     NaN
# Name: Points Scored, dtype: float64

# %%
df4[6][:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Projects\Github\Python-DataScience-Masterclass\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 6
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df4[6][:]
#
# ...

# %%
df4[df4.columns[6]]
# Out:
# 0     22.0
# 1     35.0
# 2     22.0
# 3     35.0
# 4     27.0
# 5     39.0
# 6     38.0
# 7     20.0
# 8     25.0
# 9     20.0
# 10    37.0
# 11    21.0
# 12    38.0
# 13    21.0
# 14    22.0
# 15    30.0
# 16    18.0
# 17    28.0
# 18    25.0
# 19    19.0
# 20    22.0
# 21    20.0
# 22    18.0
# 23    36.0
# 24    19.0
# 25    36.0
# 26    30.0
# 27    34.0
# 28    37.0
# 29    35.0
# 30    20.0
# 31    35.0
# 32    19.0
# 33    25.0
# 34    40.0
# 35    18.0
# 36    18.0
# 37    31.0
# 38    29.0
# 39    28.0
# 40     NaN
# 41     NaN
# 42     NaN
# 43     NaN
# Name: Minutes Played, dtype: float64

# %%
## Summary stats using NumPy

import numpy as np

data = np.array(df4[df4.columns[6]][:39])

print(f"Count      : {data.size}")
print(f"Mean       : {np.mean(data):.2f}")
print(f"Median     : {np.median(data):.2f}")
print(f"Std (pop)  : {np.std(data):.2f}")              # Default: ddof=0 (population)
print(f"Std (sam)  : {np.std(data, ddof=1):.2f}")      # ddof=1 for sample
print(f"Var (pop)  : {np.var(data):.2f}")
print(f"Min        : {np.min(data)}")
print(f"Max        : {np.max(data)}")
print(f"Sum        : {np.sum(data)}")

# Percentiles
print(f"25th pctile: {np.percentile(data, 25):.2f}")
print(f"50th pctile: {np.percentile(data, 50):.2f}")   # Same as median
print(f"75th pctile: {np.percentile(data, 75):.2f}")
print(f"90th pctile: {np.percentile(data, 90):.2f}")
# Out:
# Count      : 39
# Mean       : 27.28
# Median     : 25.00
# Std (pop)  : 7.43
# Std (sam)  : 7.53
# Var (pop)  : 55.23
# Min        : 18.0
# Max        : 40.0
# Sum        : 1064.0
# 25th pctile: 20.00
# 50th pctile: 25.00
# 75th pctile: 35.00
# 90th pctile: 37.20

# %%
df4.tail(5)
# Out:
#      Match Date    Team Opponent                  Venue Player    Grade  \
# 39  26-Mar-2026  Tigers  Knights            River Court   Ryan  Grade 8
# 40          NaN     NaN      NaN  for loop from 1 to 14    NaN      NaN
# 41          NaN     NaN       14                     41    574      NaN
# 42          NaN     NaN      NaN                    NaN    NaN      NaN
# 43          NaN     NaN      NaN                 2Dlist    NaN      NaN
#
#     Minutes Played  Points Scored Assists       Rebounds  Fouls  \
# 39            28.0           18.0      11             10    4.0
# 40             NaN            NaN     NaN            NaN    NaN
# 41             NaN            NaN     NaN            NaN    NaN
# 42             NaN            NaN      PT  14 attributes    NaN
# 43             NaN            NaN     NaN            NaN    NaN
#
#    Ticket Sales ($)       Coach Match Result
# 39           $1,421  Coach Nina          Win
# 40              NaN         NaN          NaN
# ...

# %%
df5 =df4[:40][:]
df5
# Out:
#      Match Date     Team  Opponent         Venue  Player    Grade  \
# 0   07-Jan-2026  Falcons    Comets   River Court    Zara  Grade 6
# 1   09-Jan-2026  Falcons    Comets  Central Dome    Zara  Grade 5
# 2   11-Jan-2026  Falcons   Rockets      Sky Hall    Lily  Grade 7
# 3   13-Jan-2026   Tigers     Storm   River Court   Aarav  Grade 8
# 4   15-Jan-2026   Sharks    Comets   North Arena    Ryan  Grade 6
# 5   17-Jan-2026   Tigers   Rockets   River Court    Lily  Grade 6
# 6   19-Jan-2026   Sharks   Rockets      Sky Hall   Ethan  Grade 7
# 7   21-Jan-2026   Sharks    Comets   River Court   Ethan  Grade 7
# 8   23-Jan-2026   Wolves  Panthers  Central Dome  Ishaan  Grade 6
# 9   25-Jan-2026   Wolves     Storm  Central Dome    Noah  Grade 8
# 10  27-Jan-2026   Wolves   Knights   North Arena   Ethan  Grade 8
# 11  29-Jan-2026  Falcons   Knights   River Court    Ryan  Grade 7
# 12  31-Jan-2026   Sharks   Knights   North Arena    Ryan  Grade 7
# ...

# %%
df4.head(5)

# %%
df4.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df4.head(5)
#
# NameError: name 'df4' is not defined
